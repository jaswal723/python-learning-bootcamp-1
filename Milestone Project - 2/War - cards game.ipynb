# %%
import random
suits = ('Hearts','Diamonds','Spades','Clubs')
ranks = ('Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace')
values = {'Two':2,'Three':3,'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10,'Jack':11,'Queen':12,'King':13,'Ace':14}

# %%
class Card:

    def __init__(self,suit,rank):
        self.suit=suit
        self.rank=rank
        self.value = values[rank]

    def __str__(self):
        return self.rank + " of " + self.suit

# %%
class Deck:
    
    def __init__(self):
        self.all_cards = []

        for suit in suits:
            for rank in ranks:
                created_card = Card(suit,rank)
                self.all_cards.append(created_card)

    def shuffle(self):
        random.shuffle(self.all_cards)

    def deal_one(self):
        return self.all_cards.pop()

# %%
class Player:

    def __init__(self,name):
        self.name = name
        self.all_cards = []

    def remove_one(self):
        return self.all_cards.pop(0)

    def add_cards(self,new_cards):
        if type(new_cards) == type([]):
            self.all_cards.extend(new_cards)
        else:
            self.all_cards.append(new_cards)

    def __str__(self):
        return f'Player {self.name} has {len(self.all_cards)} cards.'

# %%
player_one = Player("One")
player_two = Player("Two")

new_deck = Deck()
new_deck.shuffle()

for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())

# %%
game_on = True

# %%
round_num = 0

while game_on:
    round_num+=1
    print(f"\nRound {round_num}, Player 1 cards - {len(player_one.all_cards)}, Player 2 cards - {len(player_two.all_cards)}")

    if len(player_one.all_cards) == 0:
        print('Player One, out of cards! Player Two Wins!')
        game_on = False
        break

    if len(player_two.all_cards) == 0:
        print('Player Two, out of cards! Player One Wins!')
        game_on = False
        break

    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())

    at_war = True

    while at_war:

        if player_one_cards[-1].value > player_two_cards[-1].value:
            print(f"{player_one_cards[-1]} vs {player_two_cards[-1]}")
            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)
            at_war = False

        elif player_one_cards[-1].value < player_two_cards[-1].value:
            print(f"{player_one_cards[-1]} vs {player_two_cards[-1]}")
            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)
            at_war = False

        else:
            print('WAR!')

            if len(player_one.all_cards) < 5:
                print("Player One unable to declare war")
                print("Player Two wins!")
                game_on = False
                break

            elif len(player_two.all_cards) < 5:
                print("Player Two unable to declare war")
                print("Player One wins!")
                game_on = False
                break

            else:
                for num in range(5):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
# Out:
# Round 1, Player 1 cards - 26, Player 2 cards - 26
# Queen of Clubs vs Seven of Diamonds
#
# Round 2, Player 1 cards - 27, Player 2 cards - 25
# Three of Diamonds vs King of Clubs
#
# Round 3, Player 1 cards - 26, Player 2 cards - 26
# Jack of Diamonds vs Queen of Spades
#
# Round 4, Player 1 cards - 25, Player 2 cards - 27
# Queen of Diamonds vs King of Hearts
#
# Round 5, Player 1 cards - 24, Player 2 cards - 28
# Nine of Hearts vs Three of Clubs
#
# Round 6, Player 1 cards - 25, Player 2 cards - 27
# Two of Diamonds vs Four of Diamonds
#
# Round 7, Player 1 cards - 24, Player 2 cards - 28
# Six of Diamonds vs Ace of Hearts
#
# Round 8, Player 1 cards - 23, Player 2 cards - 29
# Five of Diamonds vs King of Diamonds
#
# Round 9, Player 1 cards - 22, Player 2 cards - 30
# Nine of Diamonds vs Ten of Spades
#
# Round 10, Player 1 cards - 21, Player 2 cards - 31
# Nine of Clubs vs King of Spades
#
# Round 11, Player 1 cards - 20, Player 2 cards - 32
# Jack of Clubs vs Three of Hearts
#
# Round 12, Player 1 cards - 21, Player 2 cards - 31
# Jack of Spades vs Two of Hearts
#
# Round 13, Player 1 cards - 22, Player 2 cards - 30
# WAR!
# Five of Hearts vs Six of Clubs
#
# Round 14, Player 1 cards - 16, Player 2 cards - 36
# Four of Clubs vs Ten of Diamonds
#
# Round 15, Player 1 cards - 15, Player 2 cards - 37
# Five of Spades vs Two of Clubs
#
# Round 16, Player 1 cards - 16, Player 2 cards - 36
# Three of Spades vs Eight of Hearts
#
# Round 17, Player 1 cards - 15, Player 2 cards - 37
# Five of Clubs vs Two of Spades
#
# Round 18, Player 1 cards - 16, Player 2 cards - 36
# Four of Hearts vs Jack of Hearts
#
# Round 19, Player 1 cards - 15, Player 2 cards - 37
# Seven of Hearts vs Nine of Spades
#
# Round 20, Player 1 cards - 14, Player 2 cards - 38
# Queen of Hearts vs Four of Spades
#
# Round 21, Player 1 cards - 15, Player 2 cards - 37
# Seven of Spades vs Eight of Spades
#
# Round 22, Player 1 cards - 14, Player 2 cards - 38
# Queen of Clubs vs Three of Diamonds
#
# Round 23, Player 1 cards - 15, Player 2 cards - 37
# Seven of Diamonds vs King of Clubs
#
# Round 24, Player 1 cards - 14, Player 2 cards - 38
# Nine of Hearts vs Jack of Diamonds
#
# Round 25, Player 1 cards - 13, Player 2 cards - 39
# Three of Clubs vs Queen of Spades
#
# Round 26, Player 1 cards - 12, Player 2 cards - 40
# Jack of Clubs vs Queen of Diamonds
#
# Round 27, Player 1 cards - 11, Player 2 cards - 41
# Three of Hearts vs King of Hearts
#
# Round 28, Player 1 cards - 10, Player 2 cards - 42
# Jack of Spades vs Two of Diamonds
#
# Round 29, Player 1 cards - 11, Player 2 cards - 41
# Two of Hearts vs Four of Diamonds
#
# Round 30, Player 1 cards - 10, Player 2 cards - 42
# Five of Spades vs Six of Diamonds
#
# Round 31, Player 1 cards - 9, Player 2 cards - 43
# Two of Clubs vs Ace of Hearts
#
# Round 32, Player 1 cards - 8, Player 2 cards - 44
# WAR!
# Three of Diamonds vs King of Spades
#
# Round 33, Player 1 cards - 2, Player 2 cards - 50
# Jack of Spades vs Six of Spades
#
# Round 34, Player 1 cards - 3, Player 2 cards - 49
# Two of Diamonds vs Eight of Diamonds
#
# Round 35, Player 1 cards - 2, Player 2 cards - 50
# Jack of Spades vs Ten of Clubs
#
# Round 36, Player 1 cards - 3, Player 2 cards - 49
# Six of Spades vs Ace of Diamonds
#
# Round 37, Player 1 cards - 2, Player 2 cards - 50
# Jack of Spades vs Ace of Clubs
#
# Round 38, Player 1 cards - 1, Player 2 cards - 51
# Ten of Clubs vs Five of Hearts
#
# Round 39, Player 1 cards - 2, Player 2 cards - 50
# Ten of Clubs vs Six of Hearts
#
# Round 40, Player 1 cards - 3, Player 2 cards - 49
# Five of Hearts vs Seven of Clubs
#
# Round 41, Player 1 cards - 2, Player 2 cards - 50
# Ten of Clubs vs Eight of Clubs
#
# Round 42, Player 1 cards - 3, Player 2 cards - 49
# Six of Hearts vs Ace of Spades
#
# Round 43, Player 1 cards - 2, Player 2 cards - 50
# WAR!
# Player One unable to declare war
# Player Two wins!
